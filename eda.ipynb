# %%
# -*- coding: utf-8 -*-
import sys; print('Python %s on %s' % (sys.version, sys.platform))
import os
import time
import json
import pandas as pd
import numpy as np
from glob import glob, iglob
from tqdm import tqdm
from datetime import datetime
import matplotlib.pyplot as plt
# Out:
# Python 3.8.10 (default, Mar 13 2023, 10:26:41)
# [GCC 9.4.0] on linux

# %% [markdown]
# ## prepare for the library and category

# %%
dict_category = {
    'general': ('ede_md', 'ede_url.csv'),
    'cop': ('ICE DE CoP_md', 'ICE DE CoP_url.csv'),
    'development': ('ICE DE Development_md', 'ICE DE Development_url.csv'),
    'support': ('ICE DE Support Model_md', 'ICE DE Support Model_url.csv'),
    'incident': ('Incidents and Lessons Learned_md', 'Incidents and Lessons Learned_url.csv'),
}

# %%
import utils
import chunk
from chunk import MAX_TOKEN

LIBRARY = 'ede-20230605'
# CATEGORY = 'ede_md'

# %%
results = []
for category, values in dict_category.items():
    DATASET_FOLDER = f'./dataset/{LIBRARY}/{values[0]}'
    data_source = sorted(iglob(DATASET_FOLDER + '**/**/*.md', recursive=True))

    df_link = pd.read_csv(f'./dataset/{LIBRARY}/{values[1]}', index_col='title')
    dict_link = { idx: item.url.lower() for idx, item in df_link.iterrows() }
    print(category, values, len(data_source), len(dict_link))
    
    for file_path in tqdm(data_source):
        try:
            plain_text = utils.preprocess_markdown_file(file_path)
            file_names = file_path.replace(DATASET_FOLDER, '').split('/')
            file_name = file_names[-1]
            external_link = dict_link[file_name]

            contents = list(chunk.recursive_split_by_heading(plain_text))
            contents = chunk.merge_short_paragraphs(contents, max_token=int(MAX_TOKEN*0.8), direction="bottom-up")
            contents = [x for x in contents if len(x.strip()) > 0]

            for idx, content in enumerate(contents):     
                results.append({
                    "library": LIBRARY,
                    "category": category,
                    "checksum": utils.generate_checksum(file_path + content),
                    "file_name": file_name,
                    "file_path": file_path,
                    "external_link": external_link,
                    "chapter": idx+1,
                    "text_length": len(content),
                    "token_count": utils.num_tokens_from_string(content),
                    "content": content
                })
        except:
            print(file_path)
            raise
# Out:
# general ('ede_md', 'ede_url.csv') 152 152
#  12%|█▏        | 18/152 [00:00<00:04, 26.83it/s]/tf/cyrano/semantic/utils.py:25: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   return BeautifulSoup(text, 'html.parser').get_text()
# 100%|██████████| 152/152 [00:03<00:00, 39.83it/s]
# cop ('ICE DE CoP_md', 'ICE DE CoP_url.csv') 13 13
# 100%|██████████| 13/13 [00:00<00:00, 64.67it/s]
# development ('ICE DE Development_md', 'ICE DE Development_url.csv') 59 59
# 100%|██████████| 59/59 [00:01<00:00, 47.72it/s]
# support ('ICE DE Support Model_md', 'ICE DE Support Model_url.csv') 6 6
# 100%|██████████| 6/6 [00:00<00:00, 27.77it/s]
# incident ('Incidents and Lessons Learned_md', 'Incidents and Lessons Learned_url.csv') 28 28
# 100%|██████████| 28/28 [00:00<00:00, 44.28it/s]

# %%
df_meta = pd.DataFrame(results)
df_meta = df_meta.set_index('checksum')
df_meta = df_meta.rename_axis('idx')
df_sorted = df_meta.sort_values(by='file_path', ascending=False)

# %%
df_meta.head(5)
# Out:
#                                                          library category
# idx
# 5321df80aa9ea2d59e5f8f24b7d47018c0e0ea05a84
# idx
# 5321df80aa9ea2d59e5f8f24b7d47018c0e0ea05a84b282...  # SITE RELIABILITY ENGINEERING(SRE)\n \n!!! wa...
# fd4123b6c6da924cb5dfa0d4a8450b29d31c8e7f53c1cb9...  # Accessing ACR\n\nWe are now using ACR(Azure ...
# 3b067677bca0eab603ee31ff3a9b482e9c2614fb8bea8ec...  # Adding a Secret to the CI Pipeline\n\nIf you...
# 7e01977015a7c6be55b97ac69db22247fe724bd2eaa4e2f...  # Admission Webhook Best Practices and Warning...
# efcacb67ddb42bd11166dfcad68b92ec7261e2d7e107a6e...  ## Availability\n\nIt is recommended that Admi...

# %%
df_meta.describe()
# Out:
#           chapter  text_length  token_count
# count  778.000000   778.000000   778.000000
# mean     3.330334  1480.877892   366.167095
# std      3.309847   881.059088   195.656537
# min      1.000000    13.000000     4.000000
# 25%      1.000000   963.000000   241.000000
# 50%      2.000000  1395.000000   354.500000
# 75%      4.000000  1808.000000   455.750000
# max     27.000000  8136.000000  1071.000000

# %%
df_meta['token_count'].sum()
# Out:
# 284878

# %%
df_meta['text_length'].sum()
# Out:
# 1152123

# %%
df_meta.index.value_counts()
# Out:
# idx
# 5321df80aa9ea2d59e5f8f24b7d47018c0e0ea05a84b28287ed13096577ffc1f    1
# 354cf2e85c818225608bd25ac77605d3f682355c2a3e8e672b4f93abdf786024    1
# a2d18eff7babe27f2e231416db57d5f130f625f1020aa5d4b7403b32b1380db8    1
# 9f10076479ff20b6025e1c8c74fd3aa2dcf10aa78790eb945548b6b706683d64    1
# b6ede053e10ebd7a94cbde11307021275f92d6659d83b993b657fccb191a2771    1
#                                                                    ..
# 4b3a3181e7d8c352b1b2fdb287086463beeb8822e7b96beee106d48993f34886    1
# b8687f9c2aecb9b65ab4f3d594d105ea0fb8d291a21461cd99a570dd0650db54    1
# 7d71f8b0d45198ee406413b2e8984ed940f8a85b3671d2049bff934875be7843    1
# ac143e4e8c4b8dbd37c8fde7edf1de8f2ef0f76a8597f3387422d62e7375fb55    1
# 713f6cdf257f88c6b3c3a669bb3968583e6497b5cc4e58f1043ed5586b853e55    1
# Name: count, Length: 778, dtype: int64

# %%
print(df_meta[df_meta['token_count'] > 1000].shape)
df_meta[df_meta['token_count'] > 1000]
# Out:
# (15, 9)
#                                                          library     category
# idx
# 94e9753c0e6f0c2573fc4f0b9b149a309bee6c64030851c...  ede-20230605      general  \
# 3aa7ffce57df6e83efea0a7836c6293a13bf0dd4f5b2e14...  ede-20230605      general
# 3e05c4932ce2476f961f2a5488c7d2c4f2d10248dbb25b6...  ede-20230605      general
# fc0bdeb9f46c25717ecaffcc7e5cff7cb75028d1e6f317d...  ede-20230605      general
# 630ba6bf1bc0e69cbe1ff2eaa669e2c0ce57519e890816e...  ede-20230605      general
# 6cccf0d3826bfb16bddf54288a453213557a7fd146a447a...  ede-20230605  development
# 2f11cac9d864ad583cbb4202a895d1d04d69c91a27b9731...  ede-20230605  development
# 0cc08483703a8fc4c0da0a36a59a5d73e620cf47c2a876b...  ede-20230605  development
# 270f159cd9e99fa7867970a6eeb5d3da9c0868adadc2b1e...  ede-20230605  development
# 9b3e43b54a27f5f95cd87b9108183182f5c9a5ae08f7b9e...  ede-20230605  development
# 6cccf0d3826bfb16bddf54288a453213557a7fd146a447a...  * [ICE DE Service Directory](/wiki/display/Eur...
# 2f11cac9d864ad583cbb4202a895d1d04d69c91a27b9731...  Category| Summary| Purpose/Component| Team| Ma...
# 0cc08483703a8fc4c0da0a36a59a5d73e620cf47c2a876b...  | Meta| [ailsa.wu@sap.com](mailto:ailsa.wu@sap...
# 270f159cd9e99fa7867970a6eeb5d3da9c0868adadc2b1e...  #### Consumer Lag dashboard  Browse → daas →[ ...
# 9b3e43b54a27f5f95cd87b9108183182f5c9a5ae08f7b9e...  ### Loki Queries  The following queries will d...
# c13ca969edfdb72523185112630401ccb456ee8a6261e02...  /:f:/p/ryder_xia/Ev9qIg6L4mdJueTV3EJtG-4Bg8ECc...
# 9adfab9915704eb9d9e0fd84a1bd019948a0132bad86250...  [tony.qu@sap.com](mailto:tony.qu@sap.com)| [ai...
# 0801e7282cbc218b00793e7f7b1b297c645d17ff24b257f...  ### EDE Component List\n\nComponent| Descripti...
# 3f699a6d7638cf68a5c5155aed3310f7eb179b35eb780a4...  # 2023-06-09 Meeting Minutes  Category| Compon...
# 1e2397a60d18a47b3e3958954e45e49ffc34d2a73e1fefe...  ### **4\. Solutions**  Conclude with **both** ...

# %%
print(df_meta[df_meta['token_count'] < 30].shape)
df_meta[df_meta['token_count'] < 30]
# Out:
# (9, 9)
#                                                          library     category
# idx
# 48de358c309644289629136837f61df32b92757695d1e35...  ede-20230605      general  \
# 0a9adfbabc0a07641a9a635eee2de1473537d7f7494bd3c...  ede-20230605      general
# f7a4c306a8d9ce1c5fe287bd33351c5653d9e8a9639c3de...  ede-20230605      general
# c7fcfa937d6d7800c00c0c5821110361d5ab2c1b7bb2212...  ede-20230605      general
# ed5257770fd50e72bcf322fae46250403a379f8fd246f07...  ede-20230605      general
# 342a366ae926ca214b6e8202eae0589b866efaf60f7ca71...  ede-20230605  development
# b555ea515a49ad89f61b613c838cd156c918b665ae6d01b...  ede-20230605  development
# 16b6f55865955c86c3bbf0606693b5f1bc5bb03ed8e819d...  ede-20230605  development
# e615f8177417ac4a2990f4b0f31209514ee6f6e7765438c...  ede-20230605  development
#
#                                                                           file_name
# idx
# 48de358c309644289629136837f61df32b92757695d1e35...                   bom-runbook.md  \
# 0a9adfbabc0a07641a9a635eee2de1473537d7f7494bd3c...                  daas-runbook.md
# f7a4c306a8d9ce1c5fe287bd33351c5653d9e8a9639c3de...  day-one-2-backend-developers.md
# c7fcfa937d6d7800c00c0c5821110361d5ab2c1b7bb2212...                   offboarding.md
# ed5257770fd50e72bcf322fae46250403a379f8fd246f07...                work-with-pact.md
# 342a366ae926ca214b6e8202eae0589b866efaf60f7ca71...      ICE DE Service Directory.md
# b555ea515a49ad89f61b613c838cd156c918b665ae6d01b...              Knative Overview.md
# 16b6f55865955c86c3bbf0606693b5f1bc5bb03ed8e819d...                    Monitoring.md
# e615f8177417ac4a2990f4b0f31209514ee6f6e7765438c...      Sealedsecret (3rd-party).md
#
# 48de358c309644289629136837f61df32b92757695d1e35...           24  \
# 0a9adfbabc0a07641a9a635eee2de1473537d7f7494bd3c...           24
# f7a4c306a8d9ce1c5fe287bd33351c5653d9e8a9639c3de...           28
# c7fcfa937d6d7800c00c0c5821110361d5ab2c1b7bb2212...            4
# ed5257770fd50e72bcf322fae46250403a379f8fd246f07...            5
# 342a366ae926ca214b6e8202eae0589b866efaf60f7ca71...           22
# b555ea515a49ad89f61b613c838cd156c918b665ae6d01b...           22
# 16b6f55865955c86c3bbf0606693b5f1bc5bb03ed8e819d...            5
# e615f8177417ac4a2990f4b0f31209514ee6f6e7765438c...            8
#
#                                                                                               content
# idx
# 48de358c309644289629136837f61df32b92757695d1e35...  # BoM Runbook\n\nThe BoM is a tool for managin...
# 0a9adfbabc0a07641a9a635eee2de1473537d7f7494bd3c...  ## More Information\n- [Working with DaaS 1.0]...
# f7a4c306a8d9ce1c5fe287bd33351c5653d9e8a9639c3de...  ## More Information\n\nFor more information ab...
# c7fcfa937d6d7800c00c0c5821110361d5ab2c1b7bb2212...                                    # Offboarding\n
# ed5257770fd50e72bcf322fae46250403a379f8fd246f07...                              # Working with Pact\n
# 342a366ae926ca214b6e8202eae0589b866efaf60f7ca71...  Note: DI services can be found [here](/wiki/di...
# b555ea515a49ad89f61b613c838cd156c918b665ae6d01b...    \n\nKnative is an Open-Source Enterprise-lev...
# 16b6f55865955c86c3bbf0606693b5f1bc5bb03ed8e819d...                          ## Helpful Dashboards\n\n
# e615f8177417ac4a2990f4b0f31209514ee6f6e7765438c...                                    ## 4.3. How\n\n

# %%
df_meta = df_meta[df_meta['token_count'] > 20]

# %%
df_meta.index.value_counts()
# Out:
# idx
# 5321df80aa9ea2d59e5f8f24b7d47018c0e0ea05a84b28287ed13096577ffc1f    1
# 3a2ed2f3dcc6c1f50293872e2f870a934a07ebe6472a4bc44b5b37466ebedacb    1
# a2d18eff7babe27f2e231416db57d5f130f625f1020aa5d4b7403b32b1380db8    1
# 9f10076479ff20b6025e1c8c74fd3aa2dcf10aa78790eb945548b6b706683d64    1
# b6ede053e10ebd7a94cbde11307021275f92d6659d83b993b657fccb191a2771    1
#                                                                    ..
# c02c7df13d6a7978bf70aaf513a3a40677998d064c53fb6f6556b35339ab2ac4    1
# 4b3a3181e7d8c352b1b2fdb287086463beeb8822e7b96beee106d48993f34886    1
# b8687f9c2aecb9b65ab4f3d594d105ea0fb8d291a21461cd99a570dd0650db54    1
# 7d71f8b0d45198ee406413b2e8984ed940f8a85b3671d2049bff934875be7843    1
# 713f6cdf257f88c6b3c3a669bb3968583e6497b5cc4e58f1043ed5586b853e55    1
# Name: count, Length: 774, dtype: int64

# %%
df_meta.token_count.describe()
# Out:
# count     774.000000
# mean      368.031008
# std       194.429837
# min        22.000000
# 25%       242.250000
# 50%       355.500000
# 75%       456.000000
# max      1071.000000
# Name: token_count, dtype: float64

# %%
df_meta.to_parquet(f'./output/meta.parquet', index='idx')
